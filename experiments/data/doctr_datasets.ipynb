# %%
# %%capture
# !pip install python-doctr
# !pip install tensorflow-addons
# !pip install ipywidgets

# %%
from doctr.datasets import CORD, SROIE
from matplotlib import pyplot as plt

# %%
cord_train_set = CORD(train=True, download=True)  # 1000 samples with test
sroie_train_set = SROIE(train=True, download=True)  # 1000 samples with test

# %%
img, target = cord_train_set[1]
plt.figure(figsize=(10, 10))
plt.imshow(img.squeeze().permute(1, 2, 0));

# %%
print(target)
# Out:
# {'boxes': array([[0.07060185, 0.37885803, 0.2337963 , 0.40895063],
#        [0.23726852, 0.37345678, 0.39814815, 0.4027778 ],
#        [0.0787037 , 0.4212963 , 0.09953704, 0.44598764],
#        [0.2175926 , 0.41203704, 0.33912036, 0.44444445],
#        [0.7476852 , 0.41203704, 0.849537  , 0.4382716 ],
#        [0.04282407, 0.5455247 , 0.3101852 , 0.5779321 ],
#        [0.7523148 , 0.53858024, 0.8587963 , 0.5648148 ],
#        [0.8402778 , 0.64506173, 0.8634259 , 0.6697531 ],
#        [0.03472222, 0.6697531 , 0.19907407, 0.69753087],
#        [0.19907407, 0.66589504, 0.29282406, 0.69598764],
#        [0.04282407, 0.6064815 , 0.24768518, 0.6365741 ],
#        [0.7523148 , 0.5925926 , 0.8518519 , 0.61882716],
#        [0.06481481, 0.47067901, 0.2534722 , 0.5023148 ],
# ...

# %%
img, target = sroie_train_set[1]
plt.figure(figsize=(10, 10))
plt.imshow(img.squeeze().permute(1, 2, 0));

# %%
print(target)
# Out:
# {'boxes': array([[0.02907916, 0.01942857, 0.21324718, 0.04685714],
#        [0.24878837, 0.15314285, 0.76090467, 0.176     ],
#        [0.42326334, 0.18057142, 0.5848142 , 0.20457143],
#        [0.21486267, 0.208     , 0.79321486, 0.22971429],
#        [0.31502423, 0.232     , 0.6946688 , 0.25485715],
#        [0.21324718, 0.25714287, 0.78998387, 0.28228572],
#        [0.39579967, 0.2857143 , 0.6187399 , 0.3062857 ],
#        [0.30371568, 0.31314287, 0.7075929 , 0.3382857 ],
#        [0.40549272, 0.352     , 0.60258484, 0.37714285],
#        [0.18578352, 0.38514286, 0.34248787, 0.40571427],
#        [0.5961228 , 0.38285714, 0.81098545, 0.40685713],
#        [0.61227787, 0.43657142, 0.66235864, 0.46057144],
#        [0.67689824, 0.43657142, 0.73344105, 0.46057144],
#        [0.7964459 , 0.43771428, 0.84814215, 0.46057144],
#        [0.17770597, 0.46285716, 0.5621971 , 0.48342857],
#        [0.63489497, 0.46285716, 0.6526656 , 0.48342857],
# ...
